# %%
import pandas as pd

# %%
df=pd.read_csv('Patient_Characteristics_Survey__PCS___2017.csv')

# %%
df
# Out:
#         Survey Year Program Category         Region Served Age Group     Sex  \
# 0              2017      RESIDENTIAL  NEW YORK CITY REGION     ADULT    MALE
# 1              2017      RESIDENTIAL   HUDSON RIVER REGION     ADULT    MALE
# 2              2017       OUTPATIENT   HUDSON RIVER REGION     ADULT    MALE
# 3              2017        INPATIENT     CENTRAL NY REGION     ADULT  FEMALE
# 4              2017      RESIDENTIAL        WESTERN REGION     ADULT    MALE
# ...             ...              ...                   ...       ...     ...
# 175921         2017       OUTPATIENT    LONG ISLAND REGION     ADULT  FEMALE
# 175922         2017       OUTPATIENT        WESTERN REGION     ADULT    MALE
# 175923         2017       OUTPATIENT        WESTERN REGION     ADULT    MALE
# 175924         2017        EMERGENCY        WESTERN REGION     ADULT  FEMALE
# 175925         2017       OUTPATIENT  NEW YORK CITY REGION     ADULT  FEMALE
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 175926 entries, 0 to 175925
# Data columns (total 67 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   Survey Year                       175926 non-null  int64
#  1   Program Category                  175926 non-null  object
#  2   Region Served                     175926 non-null  object
#  3   Age Group                         175926 non-null  object
#  4   Sex                               175926 non-null  object
#  5   Transgender                       175926 non-null  object
#  6   Sexual Orientation                175926 non-null  object
#  7   Hispanic Ethnicity                175926 non-null  object
#  8   Race                              175926 non-null  object
#  9   Living Situation                  175926 non-null  object
#  10  Household Composition             175926 non-null  object
# ...

# %%
pd.options.display.max_rows = 200000
df.isnull().sum()
# Out:
# Survey Year                         0
# Program Category                    0
# Region Served                       0
# Age Group                           0
# Sex                                 0
# Transgender                         0
# Sexual Orientation                  0
# Hispanic Ethnicity                  0
# Race                                0
# Living Situation                    0
# Household Composition               0
# Preferred Language                  0
# Veteran Status                      0
# Employment Status                   0
# Number Of Hours Worked Each Week    0
# Education Status                    0
# Special Education Services          0
# Mental Illness                      0
# Intellectual Disability             0
# Autism Spectrum                     0
# Other Developmental Disability      0
# Alcohol Related Disorder            0
# Drug Substance Disorder             0
# Mobility Impairment Disorder        0
# Hearing Visual Impairment           0
# ...

# %%
pd.reset_option("all")
# Out:
# C:\Users\Desktop\anaconda3\lib\site-packages\pandas\_config\config.py:653: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead.
#   warnings.warn(d.msg, FutureWarning)
# C:\Users\Desktop\anaconda3\lib\site-packages\pandas\_config\config.py:653: FutureWarning:
# : boolean
#     use_inf_as_null had been deprecated and will be removed in a future
#     version. Use `use_inf_as_na` instead.
#
#   warnings.warn(d.msg, FutureWarning)

# %%
df=df.drop(['Survey Year','Program Category','Living Situation','Household Composition',
            'Preferred Language', 'Number Of Hours Worked Each Week',
            'Special Education Services','Other Developmental Disability','Other Chronic Med Condition', 
            'No Chronic Med Condition','Unknown Chronic Med Condition',
            'Received Smoking Counseling', 'Principal Diagnosis Class',
            'Additional Diagnosis Class', 'SSI Cash Assistance','SSDI Cash Assistance', 'Veterans Disability Benefits',
            'Veterans Cash Assistance', 'Public Assistance Cash Program','Other Cash Benefits', 
            'Medicaid and Medicare Insurance','Unknown Insurance Coverage', 'No Insurance', 'Medicaid Insurance',
            'Medicaid Managed Insurance', 'Medicare Insurance', 'Private Insurance','Child Health Plus Insurance', 
            'Other Insurance','Criminal Justice Status', 'Three Digit Residence Zip Code'], axis=1)

# %%
'''
df=df.drop(['Survey Year','Program Category','Living Situation','Household Composition',
            'Preferred Language','Veteran Status','Number Of Hours Worked Each Week',
            'Special Education Services','Other Developmental Disability','Other Chronic Med Condition', 
            'No Chronic Med Condition','Unknown Chronic Med Condition', 'Smokes','Received Smoking Medication',
            'Received Smoking Counseling','Serious Mental Illness', 'Principal Diagnosis Class',
            'Additional Diagnosis Class', 'SSI Cash Assistance','SSDI Cash Assistance', 'Veterans Disability Benefits',
            'Veterans Cash Assistance', 'Public Assistance Cash Program','Other Cash Benefits', 
            'Medicaid and Medicare Insurance','Unknown Insurance Coverage', 'No Insurance', 'Medicaid Insurance',
            'Medicaid Managed Insurance', 'Medicare Insurance', 'Private Insurance','Child Health Plus Insurance', 
            'Other Insurance','Criminal Justice Status', 'Three Digit Residence Zip Code'], axis=1)
'''
# Out:
# "\ndf=df.drop(['Survey Year','Program Category','Living Situation','Household Composition',\n            'Preferred Language','Veteran Status','Number Of Hours Worked Each Week',\n            'Special Education Services','Other Developmental Disability','Other Chronic Med Condition', \n            'No Chronic Med Condition','Unknown Chronic Med Condition', 'Smokes','Received Smoking Medication',\n            'Received Smoking Counseling','Serious Mental Illness', 'Principal Diagnosis Class',\n            'Additional Diagnosis Class', 'SSI Cash Assistance','SSDI Cash Assistance', 'Veterans Disability Benefits',\n            'Veterans Cash Assistance', 'Public Assistance Cash Program','Other Cash Benefits', \n            'Medicaid and Medicare Insurance','Unknown Insurance Coverage', 'No Insurance', 'Medicaid Insurance',\n            'Medicaid Managed Insurance', 'Medicare Insurance', 'Private Insurance','Child Health Plus Insurance', \n            'Other Insurance','Criminal Justice S
# ...

# %%
df.columns
# Out:
# Index(['Region Served', 'Age Group', 'Sex', 'Transgender',
#        'Sexual Orientation', 'Hispanic Ethnicity', 'Race', 'Veteran Status',
#        'Employment Status', 'Education Status', 'Mental Illness',
#        'Intellectual Disability', 'Autism Spectrum',
#        'Alcohol Related Disorder', 'Drug Substance Disorder',
#        'Mobility Impairment Disorder', 'Hearing Visual Impairment',
#        'Hyperlipidemia', 'High Blood Pressure', 'Diabetes', 'Obesity',
#        'Heart Attack', 'Stroke', 'Other Cardiac', 'Pulmonary Asthma',
#        'Alzheimer or Dementia', 'Kidney Disease', 'Liver Disease',
#        'Endocrine Condition', 'Neurological Condition',
#        'Traumatic Brain Injury', 'Joint Disease', 'Cancer', 'Smokes',
#        'Received Smoking Medication', 'Serious Mental Illness'],
#       dtype='object')

# %%
for i in df.columns:
    x = df[i].value_counts()
    print(x)
    print()
# Out:
# NEW YORK CITY REGION    87379
# WESTERN REGION          30091
# HUDSON RIVER REGION     26744
# CENTRAL NY REGION       19128
# LONG ISLAND REGION      12584
# Name: Region Served, dtype: int64
#
# ADULT      140506
# CHILD       35387
# UNKNOWN        33
# Name: Age Group, dtype: int64
#
# FEMALE     88198
# MALE       87534
# UNKNOWN      194
# Name: Sex, dtype: int64
#
# NO, NOT TRANSGENDER     166623
# UNKNOWN                   5941
# YES, TRANSGENDER          1844
# CLIENT DIDN'T ANSWER      1518
# Name: Transgender, dtype: int64
#
# STRAIGHT OR HETEROSEXUAL    138762
# UNKNOWN                      19845
# LESBIAN OR GAY                5416
# CLIENT DID NOT ANSWER         5302
# BISEXUAL                      4976
# OTHER                         1625
# Name: Sexual Orientation, dtype: int64
#
# NO, NOT HISPANIC/LATINO    130876
# YES, HISPANIC/LATINO        41501
# UNKNOWN                      3549
# Name: Hispanic Ethnicity, dtype: int64
#
# WHITE ONLY      90099
# ...

# %%
df1 = df.apply(lambda x: x.str.replace('.*UNKNOWN.*', 'UNKNOWN', regex=True))

# %%
df1.apply(lambda col: col.str.contains('UNKNOWN').sum())
# Out:
# Region Served                       0
# Age Group                          33
# Sex                               194
# Transgender                      5941
# Sexual Orientation              19845
# Hispanic Ethnicity               3549
# Race                             5653
# Veteran Status                   4754
# Employment Status                5167
# Education Status                16400
# Mental Illness                   1182
# Intellectual Disability         12008
# Autism Spectrum                 10843
# Alcohol Related Disorder         7425
# Drug Substance Disorder          7338
# Mobility Impairment Disorder     9853
# Hearing Visual Impairment        9947
# Hyperlipidemia                  21271
# High Blood Pressure             21271
# Diabetes                        21271
# Obesity                         21271
# Heart Attack                    21271
# Stroke                          21271
# Other Cardiac                   21271
# Pulmonary Asthma                21271
# ...

# %%
for i in df1.columns:
    x = df1[i].value_counts()
    print(x)
    print()
# Out:
# NEW YORK CITY REGION    87379
# WESTERN REGION          30091
# HUDSON RIVER REGION     26744
# CENTRAL NY REGION       19128
# LONG ISLAND REGION      12584
# Name: Region Served, dtype: int64
#
# ADULT      140506
# CHILD       35387
# UNKNOWN        33
# Name: Age Group, dtype: int64
#
# FEMALE     88198
# MALE       87534
# UNKNOWN      194
# Name: Sex, dtype: int64
#
# NO, NOT TRANSGENDER     166623
# UNKNOWN                   5941
# YES, TRANSGENDER          1844
# CLIENT DIDN'T ANSWER      1518
# Name: Transgender, dtype: int64
#
# STRAIGHT OR HETEROSEXUAL    138762
# UNKNOWN                      19845
# LESBIAN OR GAY                5416
# CLIENT DID NOT ANSWER         5302
# BISEXUAL                      4976
# OTHER                         1625
# Name: Sexual Orientation, dtype: int64
#
# NO, NOT HISPANIC/LATINO    130876
# YES, HISPANIC/LATINO        41501
# UNKNOWN                      3549
# Name: Hispanic Ethnicity, dtype: int64
#
# WHITE ONLY      90099
# ...

# %%
df1.replace(['NO, NOT TRANSGENDER', 'YES, TRANSGENDER', "CLIENT DIDN'T ANSWER", 'CLIENT DID NOT ANSWER', 'MULTI-RACIAL', 'NO, NOT HISPANIC/LATINO', 'YES, HISPANIC/LATINO', 'NOT IN LABOR FORCE:UNEMPLOYED AND NOT LOOKING FOR WORK', 'UNEMPLOYED, LOOKING FOR WORK'], 
            ['NO', 'YES', 'UNKNOWN', 'UNKNOWN', 'OTHER', 'NO', 'YES', 'UNEMPLOYED', 'UNEMPLOYED'], inplace=True)

# %%
for i in df1.columns:
    x = df1[i].value_counts()
    print(x)
    print()
# Out:
# NEW YORK CITY REGION    87379
# WESTERN REGION          30091
# HUDSON RIVER REGION     26744
# CENTRAL NY REGION       19128
# LONG ISLAND REGION      12584
# Name: Region Served, dtype: int64
#
# ADULT      140506
# CHILD       35387
# UNKNOWN        33
# Name: Age Group, dtype: int64
#
# FEMALE     88198
# MALE       87534
# UNKNOWN      194
# Name: Sex, dtype: int64
#
# NO         166623
# UNKNOWN      7459
# YES          1844
# Name: Transgender, dtype: int64
#
# STRAIGHT OR HETEROSEXUAL    138762
# UNKNOWN                      25147
# LESBIAN OR GAY                5416
# BISEXUAL                      4976
# OTHER                         1625
# Name: Sexual Orientation, dtype: int64
#
# NO         130876
# YES         41501
# UNKNOWN      3549
# Name: Hispanic Ethnicity, dtype: int64
#
# WHITE ONLY    90099
# BLACK ONLY    46290
# OTHER         33884
# UNKNOWN        5653
# Name: Race, dtype: int64
#
# NO         166647
# UNKNOWN      4754
# YES          4525
# ...

# %%
df_unknown=df1[df1.apply(lambda row: 'UNKNOWN' in row.values, axis=1)]
len(df_unknown)
# Out:
# 57940

# %%
len(df_unknown)/len(df1)*100
# Out:
# 32.934301922399186

# %%
df2 = df1.drop(df_unknown.index)
df2
# Out:
#                Region Served Age Group     Sex Transgender  \
# 0       NEW YORK CITY REGION     ADULT    MALE          NO
# 3          CENTRAL NY REGION     ADULT  FEMALE          NO
# 4             WESTERN REGION     ADULT    MALE          NO
# 5          CENTRAL NY REGION     CHILD  FEMALE          NO
# 6        HUDSON RIVER REGION     ADULT  FEMALE          NO
# ...                      ...       ...     ...         ...
# 175921    LONG ISLAND REGION     ADULT  FEMALE          NO
# 175922        WESTERN REGION     ADULT    MALE          NO
# 175923        WESTERN REGION     ADULT    MALE          NO
# 175924        WESTERN REGION     ADULT  FEMALE          NO
# 175925  NEW YORK CITY REGION     ADULT  FEMALE          NO
#
#               Sexual Orientation Hispanic Ethnicity        Race  \
# 0       STRAIGHT OR HETEROSEXUAL                 NO  BLACK ONLY
# 3                       BISEXUAL                 NO  BLACK ONLY
# ...

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine("mysql+pymysql://{user}:{pw}@localhost/{db}"
                       .format(user="root",
                               pw="mysql8033",
                               db="project"))

# %%
df2.to_sql(con=engine, name='patient', if_exists='replace', index=False)
# Out:
# 117986
